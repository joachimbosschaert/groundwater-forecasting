# %% [markdown]
# ## Create LSTM models to forecast depth to ground water
# - Use multiple features to predict depth to groundwater

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, TimeDistributed, BatchNormalization, Dense, Dropout
from tensorflow.random import set_seed
from tensorflow.keras.regularizers import L1L2
# Out:
# 2025-02-18 14:23:08.318969: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-18 14:23:08.319737: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-18 14:23:08.322176: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-18 14:23:08.328929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-18 14:23:08.339220: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-18 14:23:08.342227: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-18 14:23:08.351023: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-18 14:23:08.870283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load preprocessed data

# %%
df = pd.read_csv("../Processed_data/processed_data.csv", index_col="Unnamed: 0")
keepcols = ["Rainfall","Depth_to_groundwater","Temperature","Drainage_Volume", "Hydrometry"]
df = df[keepcols]
df.head()
# Out:
#    Rainfall  Depth_to_groundwater  Temperature  Drainage_Volume  Hydrometry
# 0       0.0                -31.14          5.2       -24530.688         2.4
# 1       0.0                -31.11          2.3       -28785.888         2.5
# 2       0.0                -31.07          4.4       -25766.208         2.4
# 3       0.0                -31.05          0.8       -27919.296         2.4
# 4       0.0                -31.01         -1.9       -29854.656         2.3

# %% [markdown]
# ## Use minmax scaler on Depth to groundwater

# %%
from sklearn.preprocessing import MinMaxScaler

### scale features
scaler = MinMaxScaler((-1,1))
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

### Create another scaler that can invert the output
output_scaler = MinMaxScaler((-1,1))
output_scaler.fit(df[["Depth_to_groundwater"]])
# Out:
# MinMaxScaler(feature_range=(-1, 1))

# %% [markdown]
# ## Parameters for the model

# %%
## set seed for reproducability
set_seed(5678)

### how many steps for future forecast
len_forecast = 10
look_back = 50
num_features = 5

## num folds
k = 10

### num nodes per layer
LSTM_layer1 = 64
LSTM_layer2 = 32
LSTM_layer3 = 32
Dense_layer1 = 32

Dropout_1 = 0.2
Dropout_2 = 0.2

# %% [markdown]
# ## Create training and testing set

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits = k)

# %% [markdown]
# ## Process time series as input for LSTM
# For LSTM, similar to any other supervised learning model we need labeled input data.
# In this case, one training example is a subset of the time series, with the label being the following value.
# For example, if we set the input length of our model to be 50 values, then an X_train would be the first 50 points of the time series, with y_train being the 51st value of the time series

# %%
def split_time_series_2D(sequence, num_features, num_steps):
    
    X = np.zeros(shape = (len(sequence) - num_steps - 1, num_features, num_steps))
    y = np.zeros(shape = len(sequence) - num_steps - 1)
        
    for i in range(len(sequence) - num_steps - 1):
        X[i] = sequence[i:i+num_steps].T
        
        try:
            y[i] = sequence.Depth_to_groundwater[i+num_steps]
        except:
            y[i] = sequence.Depth_to_groundwater.iloc[i+num_steps]
        
    return X, y

# %% [markdown]
# ## Create training set
# Create training set to train the model
# Create holdout set to compare performance with ARIMA model

# %%
start_index = -len_forecast

X = None
y = None

for fold, (train_index, holdout_index) in enumerate(tscv.split(df_scaled)):
    train_sequence = train_index[start_index + len_forecast:]
    start_index = train_index[-1]
    
    split_sequence = df_scaled.loc[train_index]
    seqX, label = split_time_series_2D(split_sequence, num_features, look_back)
    
    

    try:
        X = np.concat([X,seqX])
        y = np.concat([y,label])
        
    except:
        X = seqX
        y = label

# %% [markdown]
# ## Split samples into training and testing
# - Xtrain & Xtest should have shape (num samples, num features, look_back)
#
# - In our case we have 1 feature and look_back has been set to 50

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.1, random_state=1234)

# %% [markdown]
# ## Add callback  to stop early

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop_callback = EarlyStopping(
    monitor = 'val_loss',
    patience = 50,
    restore_best_weights=True)

# %% [markdown]
# ## A note on overfitting
# In previous iterations, the model had been overfitting, Various actions were taken to prevent this from happening
# - Adding dropout layers. Strangely this increased overfitting.
# - Regularizing the weights using L1 and L2 regularization. This performed quite well
# - Time distributed batch normalization between LSTM layers
#     - This slowed training, and model did not converged to a higher loss
# - Tried Batchnormalization on input data,
#     - this significantly slowed training, and model converged to higher loss
# - Add callback evaluated on validation loss, find model with the lowest validation loss

# %% [markdown]
# ## Create the model

# %%
#### initialize the regularizer
reg1 = L1L2(l1 = 4e-5, l2 = 4e-5)

#### the model
model = Sequential()

#model.add(BatchNormalization(input_shape=(1, look_back)))         
model.add(LSTM(LSTM_layer1, activation='relu', return_sequences=True, input_shape=(1, look_back), kernel_regularizer=reg1))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(Dropout(0.05))

model.add(LSTM(LSTM_layer2, activation='relu',return_sequences=True))
model.add(LSTM(LSTM_layer3, activation='relu'))

model.add(Dense(Dense_layer1, activation = 'relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
# Out:
# 2025-02-18 14:23:14.405968: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-18 14:23:14.406011: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:135] retrieving CUDA diagnostic information for host: Hotdog-Ubuntu
# 2025-02-18 14:23:14.406017: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:142] hostname: Hotdog-Ubuntu
# 2025-02-18 14:23:14.406208: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:166] libcuda reported version is: 470.256.2
# 2025-02-18 14:23:14.406231: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] kernel reported version is: 470.256.2
# 2025-02-18 14:23:14.406235: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:249] kernel version seems to match DSO: 470.256.2

# %% [markdown]
# ## Fit the model

# %%
history = model.fit(Xtrain, ytrain,
                  validation_data=(Xtest, ytest),
                  epochs=500, 
                  callbacks=early_stop_callback,
                  verbose=2)
# Out:
# Epoch 1/500
# 106/106 - 4s - 38ms/step - loss: 0.0875 - val_loss: 0.0331
# Epoch 2/500
# 106/106 - 0s - 3ms/step - loss: 0.0258 - val_loss: 0.0203
# Epoch 3/500
# 106/106 - 0s - 3ms/step - loss: 0.0181 - val_loss: 0.0153
# Epoch 4/500
# 106/106 - 0s - 3ms/step - loss: 0.0139 - val_loss: 0.0121
# Epoch 5/500
# 106/106 - 0s - 3ms/step - loss: 0.0111 - val_loss: 0.0099
# Epoch 6/500
# 106/106 - 0s - 3ms/step - loss: 0.0091 - val_loss: 0.0082
# Epoch 7/500
# 106/106 - 0s - 3ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 8/500
# 106/106 - 0s - 3ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 9/500
# 106/106 - 0s - 3ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 10/500
# 106/106 - 0s - 3ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 11/500
# 106/106 - 0s - 3ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 12/500
# 106/106 - 0s - 3ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 13/500
# 106/106 - 0s - 3ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/500
# 106/106 - 0s - 3ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 15/500
# 106/106 - 0s - 3ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 16/500
# 106/106 - 0s - 3ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 17/500
# 106/106 - 0s - 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 18/500
# 106/106 - 0s - 3ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 19/500
# 106/106 - 0s - 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 20/500
# 106/106 - 0s - 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 21/500
# 106/106 - 0s - 3ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 22/500
# 106/106 - 0s - 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 23/500
# 106/106 - 0s - 3ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 24/500
# 106/106 - 0s - 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 25/500
# 106/106 - 0s - 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 26/500
# 106/106 - 0s - 3ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 27/500
# 106/106 - 0s - 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/500
# 106/106 - 0s - 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 29/500
# 106/106 - 0s - 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 30/500
# 106/106 - 0s - 3ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 31/500
# 106/106 - 0s - 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 32/500
# 106/106 - 0s - 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 33/500
# 106/106 - 0s - 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 34/500
# 106/106 - 0s - 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 35/500
# 106/106 - 0s - 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 36/500
# 106/106 - 0s - 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 37/500
# 106/106 - 0s - 3ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 38/500
# 106/106 - 0s - 3ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 39/500
# 106/106 - 0s - 3ms/step - loss: 0.0011 - val_loss: 9.4567e-04
# Epoch 40/500
# 106/106 - 0s - 3ms/step - loss: 9.5742e-04 - val_loss: 0.0010
# Epoch 41/500
# 106/106 - 0s - 3ms/step - loss: 9.8803e-04 - val_loss: 0.0010
# Epoch 42/500
# 106/106 - 0s - 3ms/step - loss: 0.0010 - val_loss: 9.5437e-04
# Epoch 43/500
# 106/106 - 0s - 3ms/step - loss: 9.5678e-04 - val_loss: 0.0021
# Epoch 44/500
# 106/106 - 0s - 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 45/500
# 106/106 - 0s - 3ms/step - loss: 9.8853e-04 - val_loss: 9.9825e-04
# Epoch 46/500
# 106/106 - 0s - 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 47/500
# 106/106 - 0s - 3ms/step - loss: 9.1805e-04 - val_loss: 7.5344e-04
# Epoch 48/500
# 106/106 - 0s - 3ms/step - loss: 0.0010 - val_loss: 9.8815e-04
# Epoch 49/500
# 106/106 - 0s - 3ms/step - loss: 9.4706e-04 - val_loss: 0.0010
# Epoch 50/500
# 106/106 - 0s - 3ms/step - loss: 9.4220e-04 - val_loss: 9.1161e-04
# Epoch 51/500
# 106/106 - 0s - 3ms/step - loss: 8.5996e-04 - val_loss: 0.0010
# 106/106 - 0s - 3ms/step - loss: 3.2010e-04 - val_loss: 2.7707e-04
# Epoch 328/500
# 106/106 - 0s - 3ms/step - loss: 3.0798e-04 - val_loss: 2.4405e-04
# Epoch 329/500
# 106/106 - 0s - 3ms/step - loss: 3.0315e-04 - val_loss: 2.4876e-04
# Epoch 330/500
# 106/106 - 0s - 3ms/step - loss: 3.1974e-04 - val_loss: 2.5961e-04
# Epoch 331/500
# 106/106 - 0s - 3ms/step - loss: 3.2188e-04 - val_loss: 2.5495e-04
# Epoch 332/500
# 106/106 - 0s - 3ms/step - loss: 3.0728e-04 - val_loss: 2.4901e-04
# Epoch 333/500
# 106/106 - 0s - 3ms/step - loss: 3.0864e-04 - val_loss: 2.4638e-04
# Epoch 334/500
# 106/106 - 0s - 3ms/step - loss: 3.1090e-04 - val_loss: 2.4740e-04
# Epoch 335/500
# 106/106 - 0s - 3ms/step - loss: 3.1748e-04 - val_loss: 2.5149e-04
# Epoch 336/500
# 106/106 - 0s - 3ms/step - loss: 3.1153e-04 - val_loss: 2.4736e-04
# Epoch 337/500
# 106/106 - 0s - 3ms/step - loss: 3.0771e-04 - val_loss: 2.4384e-04
# Epoch 338/500
# 106/106 - 0s - 3ms/step - loss: 3.0511e-04 - val_loss: 2.6203e-04

# %% [markdown]
# ## Plot traning & validation loss functions

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = np.arange(1, len(train_loss) + 1)

skipstep = 5

plt.figure(figsize=(10,8))
plt.plot(epochs[skipstep:], train_loss[skipstep:], label = "training loss", linewidth = 2, alpha = 0.9)
plt.plot(epochs[skipstep:], val_loss[skipstep:], label = "validation loss", linewidth = 2, alpha = 0.9)

plt.legend()

# %% [markdown]
# # Look at performance of the model on the test set
# - Evaluate predicting the next value
# - We cannot predict 10 steps into the future with this model, since this would mean forecasting a value for the other features

# %% [markdown]
# ## Predict next value

# %%
#fig, ax = plt.subplots(5,2, figsize = (16,12))

MSE_scores = []
MAE_scores = []

fig, ax = plt.subplots(5,2, figsize = (16,12))

for fold, (train_index, holdout_index) in enumerate(tscv.split(df_scaled)):
    
    ax2 = int(fold/5)
    ax1 = int(fold%5)
#     print(ax1, ax2)
    
    #### create holdout sets using split_time_series
    holdout_index = np.concatenate([np.arange(holdout_index[0]-look_back, holdout_index[0]), holdout_index])
    train, holdout = df_scaled.loc[train_index], df_scaled.loc[holdout_index]
        
    X_holdout, y_holdout = split_time_series_2D(holdout, num_features, look_back)
        
    #### generate models predictions
    predictions = model.predict(X_holdout)
    print(predictions.shape)
    ##scale back to normal
    predictions_inv = output_scaler.inverse_transform(predictions)
    
    ### get mse and mae
    mse = mean_squared_error(y_holdout, predictions_inv)
    mae = mean_absolute_error(y_holdout, predictions_inv)

    MSE_scores.append(mse)
    MAE_scores.append(mae)
    
    
    #### plot test and predicted
    ax[ax1, ax2].plot(holdout_index[:], df.Depth_to_groundwater[holdout_index[:]], color="black", label=f"Actual Fold {fold}")  # Test actuals
    ax[ax1, ax2].plot(holdout_index[look_back+1:], predictions_inv[:], color="red", linestyle="dashed", label=f"Predicted Fold {fold}")  # Predictions

    # Confidence interval shading
    #ax[ax1, ax2].fill_between(test_index[:10], upper_conf_trans, lower_conf_trans, color='red', alpha=0.2)
    ax[ax1, ax2].plot(train_index[-200:], df.Depth_to_groundwater[train_index[-200:]], color='blue', label ="original time series")
    ax[ax1, ax2].legend(loc="upper left")
    
fig.suptitle("Next value Predictions vs actuals for all folds", fontsize=20)
plt.tight_layout()
# Out:
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)
# (380, 5, 50)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (380, 1)

# %% [markdown]
# ## Parameter tuning
# - using grid search find optimal hyper parameter
# - This will be evaluated on the test set, not the holdout set
#
# - We will tune Units, L1, and L2,

# %%
def create_model(units, L1, L2):
    #### initialize the regularizer
    reg1 = L1L2(l1 = L1, l2 = L2)

    #### the model
    model = Sequential()

    #model.add(BatchNormalization(input_shape=(1, look_back)))         
    model.add(LSTM(units, activation='relu', return_sequences=True, input_shape=(1, look_back), kernel_regularizer=reg1))


    model.add(LSTM(int(units*5), activation='relu',return_sequences=True))
    model.add(LSTM(int(units*3), activation='relu'))

    model.add(Dense(Dense_layer1, activation = 'relu'))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mse')
    
    return model

# %% [markdown]
# ## Perform grid search
# - Tried to use scikeras wrapper Kerasclassifier with sklearn.model_selection.GridSearchCV to perform the grid search, but this only worked for a specific set of parameters, (not *L1* and *L2*)
# - Manually perform grid search by looping through all combinations
# - Use Kfold cross validation to evaluate model performance on the training set

# %%
### define dictionary of search combinations
from itertools import product

param_grid = {
    'units' : [32, 64, 96], 
    'L1' : [2e-5, 3e-5, 4e-5],
    'L2' : [2e-5, 3e-5, 4e-5],
}

param_names = param_grid.keys()
param_vals = param_grid.values()

combinations = [dict(zip(param_names, combo)) for combo in product(*param_vals)]

# %%
### define Kfolds
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
model_val_loss = {}
best_model = None
best_loss = np.float16('inf')

for combo in combinations[:]:

    loss_vals = []
    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        
        #### define training and validation data for each fold
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        ### initialize the callback
        early_stop_callback = EarlyStopping(
                                    monitor = 'val_loss',
                                    patience = 50,
                                    restore_best_weights=True)
        
        ## define model, redefine for every fold so the weights are reset
        ## model parameters defined by combo
        model = create_model(combo['units'],combo['L1'],combo['L2'])

        
        ## fit model to data for given fold
        history = model.fit(X_train, y_train,
                              validation_data=(X_val, y_val),
                              epochs=500, 
                              callbacks=early_stop_callback,
                              verbose=0)
        
        ### use validation loss as performance metric
        loss_vals.append(min(history.history["val_loss"]))
    
    ### get the average validation loss for a parameter selection
    mean_loss = np.mean(loss_vals) 
    model_val_loss[str(combo)] = mean_loss
    
    print(combo, np.mean(loss_vals))
    
    ## if its the best model, save it
    if mean_loss < best_loss:
        print("new best model")
        best_loss = mean_loss
        best_model = model

# %% [markdown]
# ## Model with best parameters
# - Best model has parameters:
# - Units = 32
#     - LSTM1 has 32 LSTM cells
#     - LSTM2 has 16 LSTM cells
#     - LSTM3 has 10 LSTM cells
# - L1 = 3e-5
# - L2 = 3e-5

# %%
##  sort dictionary based on validation loss
sorted(model_val_loss.items(), key = lambda x:x[1])
# Out:
# [("{'units': 32, 'L1': 3e-05, 'L2': 3e-05}", 0.0001851060922490433),
#  ("{'units': 64, 'L1': 2e-05, 'L2': 2e-05}", 0.00020202154119033366),
#  ("{'units': 32, 'L1': 2e-05, 'L2': 2e-05}", 0.00021320995001588016),
#  ("{'units': 32, 'L1': 3e-05, 'L2': 4e-05}", 0.00021459051640704274),
#  ("{'units': 32, 'L1': 2e-05, 'L2': 3e-05}", 0.00021579584863502533),
#  ("{'units': 32, 'L1': 4e-05, 'L2': 4e-05}", 0.00023052791075315327),
#  ("{'units': 32, 'L1': 4e-05, 'L2': 3e-05}", 0.0002316381403943524),
#  ("{'units': 64, 'L1': 2e-05, 'L2': 3e-05}", 0.00023481601965613663),
#  ("{'units': 32, 'L1': 3e-05, 'L2': 2e-05}", 0.0002352532814256847),
#  ("{'units': 32, 'L1': 2e-05, 'L2': 4e-05}", 0.00023810665297787636),
#  ("{'units': 64, 'L1': 2e-05, 'L2': 4e-05}", 0.00026594524388201535),
#  ("{'units': 96, 'L1': 2e-05, 'L2': 3e-05}", 0.00027291222650092093),
#  ("{'units': 96, 'L1': 2e-05, 'L2': 4e-05}", 0.0002855566854123026),
#  ("{'units': 64, 'L1': 4e-05, 'L2': 3e-05}", 0.0002885209018131718),
#  ("{'units': 32, 'L1': 4e-05, 'L2': 2e-05}", 0.0002895208599511534),
#  ("{'units': 64, 'L1': 3e-05, 'L2': 4e-05}", 0.0002995074901264161),
#  ("{'units': 96, 'L1': 2e-05, 'L2': 2e-05}", 0.0003004182974109426),
#  ("{'units': 64, 'L1': 3e-05, 'L2': 3e-05}", 0.00030056947143748404),
#  ("{'units': 64, 'L1': 3e-05, 'L2': 2e-05}", 0.00031569055281579497),
#  ("{'units': 64, 'L1': 4e-05, 'L2': 4e-05}", 0.0003198006714228541),
#  ("{'units': 96, 'L1': 3e-05, 'L2': 2e-05}", 0.00032200768764596434),
#  ("{'units': 64, 'L1': 4e-05, 'L2': 2e-05}", 0.00032480052032042296),
#  ("{'units': 96, 'L1': 3e-05, 'L2': 4e-05}", 0.00033011505147442224),
#  ("{'units': 96, 'L1': 3e-05, 'L2': 3e-05}", 0.00033643375791143627),
#  ("{'units': 96, 'L1': 4e-05, 'L2': 2e-05}", 0.0003428805619478226),
#  ("{'units': 96, 'L1': 4e-05, 'L2': 4e-05}", 0.00034537779865786435),
#  ("{'units': 96, 'L1': 4e-05, 'L2': 3e-05}", 0.0003717433835845441)]
